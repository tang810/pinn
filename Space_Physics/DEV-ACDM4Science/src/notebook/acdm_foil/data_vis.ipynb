# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("/home/chunyang/projects/DDPM4Science/data/airfoil_stable/train_6k/2032c_4460_113.npz")
d = data['a']
print(d.shape)
print(type(data), type(d))
# Out:
# (6, 128, 128)
# <class 'numpy.lib.npyio.NpzFile'> <class 'numpy.ndarray'>

# %%
for i in range(d.shape[0]):
    plt.imshow(d[i, :, :])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       2 plt.imshow(d[i, :, :])
#       3 plt.show()
# ----> 4 plt.shape()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shape'
