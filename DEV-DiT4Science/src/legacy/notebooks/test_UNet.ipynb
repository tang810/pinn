# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn

import os, sys
sys.path.append("./")
sys.path.append("../")

from dit4science.model.DfpNet import TurbNetG
from dit4science.model.UNet import UNet, DownBlock, UpBlock

# %%
dummy = torch.randn((32, 4, 16, 16))

# %%
down_net = DownBlock(in_c=4, out_c=4)

# %%
down_net(down_net(down_net(down_net(dummy)))).shape
# Out:
# torch.Size([32, 4, 1, 1])

# %%
up_net = UpBlock(in_c=4, out_c=4)

# %%
dummy_small = torch.randn((32, 4, 1, 1))

# %%
up_net(dummy_small).shape
# Out:
# torch.Size([32, 4, 2, 2])

# %%
net = UNet()
net(dummy).shape
# Out:
# torch.Size([32, 4, 16, 16])
